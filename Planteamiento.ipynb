# %% [markdown]
# ¡Arratsaldeon! A continuación te explico cómo desarrollar paso a paso la práctica de Git y GitHub que aparece en el PDF, con instrucciones claras para que podáis organizaros en equipo y cumplir todos los requisitos:
#
# ---
#
# ## 🧪 Simulación de trabajo colaborativo con Git y GitHub
#
# ### 1. ✅ Preparativos iniciales
#
# #### a. Crear el repositorio en GitHub
#
# * Un miembro del equipo debe crear un **repositorio nuevo** en GitHub (ej: `proyecto-equipo`).
# * El resto debe ser añadido como **colaborador** desde *Settings > Collaborators*.
# * Clonar el repositorio localmente:
#
# ```bash
# git clone https://github.com/usuario/proyecto-equipo.git
# cd proyecto-equipo
# ```
#
# #### b. Estructura base del proyecto
#
# Cread una estructura simple en Python. Por ejemplo:
#
# ```
# proyecto-equipo/
# ├── main.py
# ├── utils/
# │   └── __init__.py
# └── README.md
# ```
#
# Subidla al repositorio (`git add`, `git commit`, `git push`).
#
# ---
#
# ### 2. 👥 Organización del equipo
#
# * Formad un equipo de **3 personas**.
# * Asignad **roles**: por ejemplo, 1 coordinador/a y 2 desarrolladores.
# * Elegid una forma de comunicaros: Discord, WhatsApp, Slack...
#
# ---
#
# ### 3. 📝 Issues y planificación
#
# * Cada persona debe **crear al menos un issue** en GitHub con una tarea técnica, y **asignarla a otro compañero**.
#
#   * Ejemplos:
#
#     * `Crear función que analice un archivo JSON`
#     * `Implementar sistema de logging`
#     * `Escribir pruebas unitarias para main.py`
#
# ---
#
# ### 4. 🚀 Flujo de trabajo profesional
#
# Para **cada tarea**, seguid este flujo:
#
# #### 1. Crear rama desde `main`
#
# ```bash
# git checkout main
# git pull
# git checkout -b feature/nombre-tarea
# ```
#
# #### 2. Trabajar en la tarea
#
# Modificar o añadir archivos para resolver el issue asignado. Hacer **commits explicativos**:
#
# ```bash
# git add archivo.py
# git commit -m "Añadir función para analizar JSON"
# ```
#
# #### 3. Subir la rama al repositorio
#
# ```bash
# git push -u origin feature/nombre-tarea
# ```
#
# #### 4. Crear Pull Request (PR)
#
# * Ir a GitHub y abrir un **Pull Request** desde la rama al `main`.
# * Pide a **otro compañero** que revise el código.
#
# #### 5. Revisión de código
#
# * Cada integrante debe **revisar al menos un PR de otro**.
# * Comentar, sugerir cambios si es necesario y aprobar.
#
# #### 6. Merge
#
# Una vez aprobado, haced el **merge** a `main` y **cerrad el issue** correspondiente.
#
# ---
#
# ### 5. ⚠ Obligatorios a cumplir
#
# * ✅ Cada uno ha creado un issue.
# * ✅ Cada uno ha hecho una tarea en su rama.
# * ✅ Cada uno ha revisado (PR) el trabajo de otro.
# * ✅ Todos han trabajado juntos en **una rama común** (ej: `feature/integracion-final`) para una tarea final grupal.
#
# ---
#
# ### 6. 🧩 Ejemplo final de trabajo grupal (opcional)
#
# Cread una tarea como:
#
# * `Integrar todas las funciones en main.py`
# * `Crear script principal que use todos los módulos`
#   Y resolvedla **entre los tres en una sola rama**, haciendo commits colaborativos.
#
# ---
#
# ¿Quieres que te dé un ejemplo concreto de tareas Python para repartir entre el equipo, o prefieres que te ayude a preparar los comandos exactos para trabajar desde consola?
