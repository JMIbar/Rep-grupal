# %% [markdown]
# Añadir segundo cambio

# %% [markdown]
# Perfecto. Aquí tienes una **guía completa con los comandos para usar Git y GitHub desde la consola**, paso a paso, adaptada al ejercicio del PDF.
#
# ---
#
# ## 🧪 GUÍA PRÁCTICA DE CONSOLA – FLUJO COMPLETO EN EQUIPO
#
# ### 🔧 1. Inicialización y clonación del repositorio
#
# **(Solo 1 persona del grupo hace esto):**
#
# ```bash
# # Crear el repositorio desde GitHub manualmente, luego:
# git clone https://github.com/usuario/proyecto-equipo.git
# cd proyecto-equipo
#
# # Crear estructura base
# mkdir utils
# touch main.py README.md utils/__init__.py
#
# # Primer commit
# git add .
# git commit -m "Estructura inicial del proyecto"
# git push origin main
# ```
#
# **(Los demás):**
#
# ```bash
# # Clonan el repositorio
# git clone https://github.com/usuario/proyecto-equipo.git
# cd proyecto-equipo
# ```
#
# ---
#
# ### 👥 2. Crear una rama para cada tarea individual
#
# Cada persona hace:
#
# ```bash
# git checkout main
# git pull
# git checkout -b feature/nombre-tarea  # Ej: feature/analizador-json
# ```
#
# ---
#
# ### 🛠 3. Trabajar en la tarea
#
# Modificar los archivos necesarios.
#
# ```bash
# # Por ejemplo:
# nano utils/json_parser.py
#
# # Añadir los archivos nuevos o modificados
# git add utils/json_parser.py
#
# # Commit explicativo
# git commit -m "Añadir analizador de archivos JSON"
# ```
#
# ---
#
# ### 🚀 4. Subir la rama a GitHub y crear el Pull Request
#
# ```bash
# # Subir la rama
# git push -u origin feature/nombre-tarea
# ```
#
# * Luego ir a GitHub y pulsar **"Compare & pull request"** para abrir el PR hacia `main`.
# * Asignar el PR a otro miembro del equipo para revisión.
#
# ---
#
# ### ✅ 5. Revisar el código de otro compañero
#
# Cada uno debe revisar **el PR de otra persona**:
#
# * Ir al PR en GitHub, mirar los cambios.
# * Comentar o aprobar.
# * Una vez aprobado, hacer el **merge**.
# * Cerrar el **issue** relacionado.
#
# ---
#
# ### 🤝 6. Tarea grupal en rama común
#
# Crear una **rama común** para integrar el trabajo final:
#
# ```bash
# git checkout main
# git pull
# git checkout -b feature/integracion-final
# ```
#
# Todos trabajáis sobre esa rama:
#
# ```bash
# # Hacer cambios colaborativos
# nano main.py
#
# # Añadir cambios
# git add main.py
# git commit -m "Integrar todas las funciones en main.py"
# git push origin feature/integracion-final
# ```
#
# * Ir rotando el trabajo o usar `git pull` para integrar el trabajo de cada uno:
#
# ```bash
# git pull origin feature/integracion-final
# ```
#
# ---
#
# ### 🧹 7. Mantenimiento final (coordinador/a)
#
# Cuando todo esté aprobado y revisado:
#
# ```bash
# # En main
# git pull
# git merge feature/integracion-final
# git push origin main
# ```
#
# ---
#
# ### 📌 Extras útiles
#
# Ver ramas:
#
# ```bash
# git branch        # locales
# git branch -r     # remotas
# ```
#
# Actualizar desde GitHub:
#
# ```bash
# git checkout main
# git pull
# ```
#
# Eliminar rama local (opcional después de merge):
#
# ```bash
# git branch -d feature/nombre-tarea
# ```
#
# ---
#
# ¿Quieres que prepare un script `.sh` con todos estos comandos para automatizar partes del flujo?
