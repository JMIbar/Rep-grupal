# %% [markdown]
# Ez horregatik! 😊 Me alegra que te sirva. Para ayudarte a estudiar mejor, aquí tienes un **guion de terminal (`practica_git.sh`)** con los comandos organizados paso a paso para practicar y repasar cuando quieras.
#
# ---
#
# ### 📁 Archivo: `practica_git.sh`
#
# ```bash
# #!/bin/bash
#
# echo "=== 1. Clonar repositorio ==="
# echo "git clone https://github.com/usuario/proyecto-equipo.git"
# echo "cd proyecto-equipo"
#
# echo "=== 2. Crear estructura base del proyecto (una sola persona) ==="
# echo "mkdir utils"
# echo "touch main.py README.md utils/__init__.py"
# echo "git add ."
# echo "git commit -m 'Estructura inicial del proyecto'"
# echo "git push origin main"
#
# echo "=== 3. Crear nueva rama para una tarea (cada persona) ==="
# echo "git checkout main"
# echo "git pull"
# echo "git checkout -b feature/nombre-tarea"
#
# echo "=== 4. Trabajar en la rama ==="
# echo "# Editar archivos, luego:"
# echo "git add archivo_modificado.py"
# echo "git commit -m 'Descripción clara del cambio'"
# echo "git push -u origin feature/nombre-tarea"
#
# echo "=== 5. Crear Pull Request desde GitHub y asignar revisión ==="
# echo "# Ir a GitHub, abrir PR desde feature/* hacia main"
#
# echo "=== 6. Revisar código de otro y aprobar ==="
# echo "# Desde GitHub: revisar PR, comentar y aprobar"
#
# echo "=== 7. Hacer merge del PR (si está aprobado) ==="
# echo "# Pulsar 'Merge' en GitHub"
# echo "# Cerrar issue relacionado"
#
# echo "=== 8. Rama común para trabajo final grupal ==="
# echo "git checkout main"
# echo "git pull"
# echo "git checkout -b feature/integracion-final"
#
# echo "# Todos hacen push, pull y commit en esta misma rama:"
# echo "git add ."
# echo "git commit -m 'Integración final del proyecto'"
# echo "git push origin feature/integracion-final"
#
# echo "=== 9. Merge final a main ==="
# echo "git checkout main"
# echo "git pull"
# echo "git merge feature/integracion-final"
# echo "git push origin main"
# ```
#
# ---
#
# ### ▶ Cómo usarlo
#
# 1. Guarda el contenido anterior como `practica_git.sh`.
# 2. Dale permisos de ejecución:
#
#    ```bash
#    chmod +x practica_git.sh
#    ```
# 3. Ejecútalo para repasarlo paso a paso:
#
#    ```bash
#    ./practica_git.sh
#    ```
#
# ---
#
# Si quieres, también puedo convertir esto en un pequeño **PDF resumen o ficha visual** para que lo tengas como chuleta. ¿Te gustaría eso?
